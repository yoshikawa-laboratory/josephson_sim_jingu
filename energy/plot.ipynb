# %%
import matplotlib.pyplot as plt
import pandas as pd
df  = pd.read_csv("/home/ttanaka/aqfp-scripts/script/skillbridge/out.csv",index_col = 0)
df.plot(subplots=True,figsize=(12,9))
#plt.savefig("4bit_adder.pdf")
# nomal state
# Out:
# array([<AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>], dtype=object)

# %%
import matplotlib.pyplot as plt
import pandas as pd
df  = pd.read_csv("/home/ttanaka/aqfp-scripts/script/skillbridge/out.csv",index_col = 0)
df.plot(subplots=True,figsize=(12,9))
# nomal state
# Out:
# array([<AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>], dtype=object)

# %%
import matplotlib.pyplot as plt
import pandas as pd
df  = pd.read_csv("00001111_2000.CSV",index_col = 0)
df.plot(subplots=True,figsize=(12,9))
# nomal state
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fadaccf6ac8>,
# ...
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import pandas as pd
df  = pd.read_csv("00001111_1000.CSV",index_col = 0)
df.plot(subplots=True,figsize=(12,9))
# nomal state
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fadacb3b278>,
# ...
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import pandas as pd
df  = pd.read_csv("00001111_500.CSV",index_col = 0)
df.plot(subplots=True,figsize=(12,9))
# nomal state
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fada6e4eda0>,
# ...
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import pandas as pd
df  = pd.read_csv("00001111_400.CSV",index_col = 0)
df.plot(subplots=True,figsize=(12,9))
# nomal state
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fada6e4e668>,
# ...
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import pandas as pd
df  = pd.read_csv("00001111_320.CSV",index_col = 0)
df.plot(subplots=True,figsize=(12,9))
# nomal state
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fada6977710>,
# ...
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import pandas as pd
df  = pd.read_csv("00001111_200.CSV",index_col = 0)
df.plot(subplots=True,figsize=(12,9))
# nomal state
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fada67607b8>,
# ...
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df  = pd.read_csv("00001111_100.CSV",index_col = 0)
df.plot(subplots=True,figsize=(12,9))
# nomal state
print(np.dot(df["I(R8)"],df["V(485,0)"])*10**-13)
print(df["I(R8)"].dot(df["V(485,0)"])*10**-13)
print(np.dot(df["I(R10)"],df["V(516,0)"])*10**-13)
print(np.dot(df["I(R8)"],df["V(492,333)"])*10**-13)
print(np.dot(df["I(R10)"],df["V(489,331)"])*10**-13)
# Out:
# 3.2838767804356646e-19
# 2.361863451367575e-19
# 2.1359807682775788e-19
# 2.7042759589624615e-19
# 3.2838767804356646e-19

# %%
import matplotlib.pyplot as plt
import pandas as pd
df  = pd.read_csv("00001110_100.CSV",index_col = 0)
df.plot(subplots=True,figsize=(12,9))
# nomal state
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fada600add8>,
# ...
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import pandas as pd
df  = pd.read_csv("a4.csv",index_col = 0)
df.plot(subplots=True,figsize=(12,9))
# nomal state
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fadac9e5c50>,
# ...
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import pandas as pd
df  = pd.read_csv("a5.csv",index_col = 0)
df.plot(subplots=True,figsize=(12,9))
# nomal state
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fadac4635f8>,
# ...
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import pandas as pd
df  = pd.read_csv("a7.csv",index_col = 0)
df.plot(subplots=True,figsize=(12,9))
# nomal state
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f63fb1a82b0>,
# ...
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import pandas as pd
df  = pd.read_csv("a9.csv",index_col = 0)
df.plot(subplots=True,figsize=(12,9))
# nomal state
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f88124f1320>,
# ...
#       dtype=object)
