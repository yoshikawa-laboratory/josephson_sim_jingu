# %%
import matplotlib.pyplot as plt
import pandas as pd
df  = pd.read_csv("out.csv",index_col = 0)
df.plot(subplots=True,figsize=(12,9))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fde02716128>,
# ...
#       dtype=object)
