# %%
import matplotlib.pyplot as plt
import pandas as pd
df  = pd.read_csv("a.txt",index_col = 0)
df.plot(subplots=True,figsize=(12,9))
# nomal state
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd35b1e4160>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fd359165550>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fd35918e9b0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fd359137e10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fd3590eb2b0>],
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import pandas as pd
df  = pd.read_csv("a2.txt",index_col = 0)
df.plot(subplots=True,figsize=(12,9))
# nomal state
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f6e32e19208>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f6e32de2588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f6e3b3629e8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f6e3b38ae48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f6e3b33c2e8>],
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import pandas as pd
df  = pd.read_csv("a4.csv",index_col = 0)
df.plot(subplots=True,figsize=(12,9))
# nomal state
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fadac9e5c50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fadac8fceb8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fadac8a62b0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fadac84c710>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fadac874b70>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fadac81dfd0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fadac7cd470>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fadac7f5908>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fadac7f5940>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fadac74e1d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fadac777630>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fadac720a90>],
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import pandas as pd
df  = pd.read_csv("a5.csv",index_col = 0)
df.plot(subplots=True,figsize=(12,9))
# nomal state
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fadac4635f8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fadac409588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fadac419940>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fadac3e8da0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fadac39a240>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fadac3c06a0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fadac368b00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fadac311f98>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fadac311fd0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fadac2ec860>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fadac293cc0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fadac2c4160>],
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import pandas as pd
df  = pd.read_csv("a7.csv",index_col = 0)
df.plot(subplots=True,figsize=(12,9))
# nomal state
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f63fb1a82b0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f63fad7a6a0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f63fada4b00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f63fad4df60>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f63facff400>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f63fad26860>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f63faccecc0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f63fac7f198>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f63fac7f1d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f63fac4da20>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f63fabf6e80>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f63fac26320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f63fabcc780>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f63fab75be0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f63faba7080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f63fab4d4e0>],
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import pandas as pd
df  = pd.read_csv("a9.csv",index_col = 0)
df.plot(subplots=True,figsize=(12,9))
# nomal state
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f88124f1320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f881249a240>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f88124766a0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f8812448b00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f880e861f60>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f880e892400>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f880e839860>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f880e7e3cf8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f880e7e3d30>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f880e7bd5c0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f880e765a20>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f880e78ce80>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f880e73e320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f880e6e3780>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f880e70cbe0>],
#       dtype=object)
